# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def ReLU(z):
    return max(0, z)

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://github.com/zetongqi/Mathematical-Machine-Learning/blob/master/network.png")
# Out:
# <img src="https://github.com/zetongqi/Mathematical-Machine-Learning/blob/master/network.png"/>

# %%
def histogram(x, a, b, theta, height):
    return ReLU(height+(b-a)/theta - 1*(ReLU(x/theta - a/theta)) + -1*(ReLU(-x/theta + b/theta)))

# %%
x = list(np.arange(0,4,0.1))

y = []
for i in x:
    y.append(histogram(i, 2, 3, 0.00000000000001, 1))

plt.plot(x, y)
